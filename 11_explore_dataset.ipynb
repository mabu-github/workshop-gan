# %% [markdown]
# # Exploring the Dataset

# %% [markdown]
# Import dataset

# %%
from util.dataset import load_mnist_data
import matplotlib.pyplot as plt

(train_images, train_labels), (test_images, test_labels) = load_mnist_data()

# %% [markdown]
# Plot dataset

# %%
width = 5
height = 5
plt.figure(figsize=(16, 12))

for i, img in enumerate(train_images[:height*width]):
    sub = plt.subplot(height, width, i+1)
    sub.get_xaxis().set_visible(False)
    sub.get_yaxis().set_visible(False)
    sub.title.set_text(f'{train_labels[i]}')
    plt.imshow(img[:, :, 0], cmap='gray')

plt.show()

# %%
print(f'Type: {type(train_images).__name__}')
print(f'Image shape: {train_images[0].shape}')
print(f'Value range: {train_images.min()}, {train_images.max()}')
# Out:
# Type: ndarray
# Image shape: (28, 28, 1)
# Value range: -1.0, 1.0
